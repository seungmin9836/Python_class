# %%
# train.csv를 읽어서 train이라는 변수에 넣기 (단, index는 PassengerId를 사용한다)

import pandas as pd

train = pd.read_csv("../Data/train.csv",index_col='PassengerId')
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# 첫줄부터 5줄 출력하기
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# 행과 열의 갯수를 출력하기
train.shape
# Out:
# (891, 11)

# %%
# train의 Survived 컬럼의 앞에서 부터 5줄 출력하기
train.Survived.head()
# Out:
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
# train의 Sex, Pclass, Survived 컬럼의 앞에서 부터 5줄 출력하기
train[['Sex','Pclass','Survived']].head()
# Out:
#                 Sex  Pclass  Survived
# PassengerId
# 1              male       3         0
# 2            female       1         1
# 3            female       3         1
# 4            female       1         1
# 5              male       3         0

# %%
# 1번부터 3번 승객까지의 데이터를 가져오기
train.iloc[0:3]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 1,3,7,13 번의 승객 데이터를 가져오기
train.iloc[[0,2,6,12]]
# Out:
#              Survived  Pclass                            Name     Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris    male  22.0
# 3                   1       3          Heikkinen, Miss. Laina  female  26.0
# 7                   0       1         McCarthy, Mr. Timothy J    male  54.0
# 13                  0       3  Saundercock, Mr. William Henry    male  20.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 7                0      0             17463  51.8625   E46        S
# 13               0      0         A/5. 2151   8.0500   NaN        S

# %%
# 1,3,7,13 번의 승객들의 Sex, Pclass, Survived 컬럼만 가져오기
train.iloc[[0,2,6,12],[3,0,1]]
# Out:
#                 Sex  Survived  Pclass
# PassengerId
# 1              male         0       3
# 3            female         1       3
# 7              male         0       1
# 13             male         0       3

# %%
# 성별이 남자인 데이터만 가져오기
train[train.Sex == 'male']
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# ...               ...     ...                             ...   ...   ...
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 890                 1       1           Behr, Mr. Karl Howell  male  26.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
# 운임요금이 20달러 이상인 데이터중 처음부터 10개만 출력하기
train[train.Fare >= 20].head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 8                   0       3
# 10                  1       2
# 12                  1       1
# 14                  0       3
# 17                  0       3
# 21                  0       2
# 24                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...

# %%
# 탑승항구가 S항구 Q항구인 데이터만 가져오기
train[(train.Embarked == 'S')|(train.Embarked == 'Q')]
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 886                 0       3          Rice, Mrs. William (Margaret Norton)
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
train[train.Embarked != 'C']
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 886                 0       3          Rice, Mrs. William (Margaret Norton)
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
embarked_list = ['Q','S']
embarked_exists = train['Embarked'].isin(embarked_list)
train[embarked_exists].head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
# 6              male   NaN      0      0            330877   8.4583   NaN
#
#             Embarked
# PassengerId
# ...

# %%
# Ticker에 STON이란 문자열이 있는 데이터 가져오기
ston_exists = train['Ticket'].str.contains("STON")
train[ston_exists].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 3                   1       3
# 116                 0       3
# 143                 1       3
# 174                 0       3
# 217                 1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 116                                      Pekoniemi, Mr. Edvard    male  21.0
# 143          Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  female  24.0
# 174                                  Sivola, Mr. Antti Wilhelm    male  21.0
# 217                                     Honkanen, Miss. Eliina  female  27.0
#
#              SibSp  Parch             Ticket    Fare Cabin Embarked
# PassengerId
# 3                0      0   STON/O2. 3101282   7.925   NaN        S
# 116              0      0  STON/O 2. 3101294   7.925   NaN        S
# 143              1      0   STON/O2. 3101279  15.850   NaN        S
# ...

# %%
# Age의 값이 NaN인 데이터 가져오기
len(train[train['Age'].isnull()])
# Out:
# 177

# %%
# Age의 값이 NaN이 아닌 데이터 가져오기
len(train[train['Age'].notnull()])
# Out:
# 714

# %%
# tilt : ~
len(train[~train['Age'].isnull()])
# Out:
# 714

# %%
null_age_or_fare = (train['Age'].isnull()) | (train['Fare'].isnull())
len(train[null_age_or_fare])
# Out:
# 177

# %%
null_age = train['Age'].isnull()
null_fare = train['Fare'].isnull()
len(train[null_age | null_fare])
# Out:
# 177

# %%
# Fare의 평균값 구하기
# Fare의 최대값 구하기

# %%
# FamilySize라는 컬럼을 생성 : SIbSP + Parch + 1
train['FamilySize'] = train['Parch'] + train['SibSp'] + 1
train[['SibSp','Parch','FamilySize']]
# Out:
#              SibSp  Parch  FamilySize
# PassengerId
# 1                1      0           2
# 2                1      0           2
# 3                0      0           1
# 4                1      0           2
# 5                0      0           1
# ...            ...    ...         ...
# 887              0      0           1
# 888              0      0           1
# 889              1      2           4
# 890              0      0           1
# 891              0      0           1
#
# [891 rows x 3 columns]

# %%
train['Nationality_AT'] = train.Embarked == 'C'
train['Nationality_UK'] = train.Embarked != 'C'
train[['Embarked','Nationality_AT','Nationality_UK']]
# Out:
#             Embarked  Nationality_AT  Nationality_UK
# PassengerId
# 1                  S           False            True
# 2                  C            True           False
# 3                  S           False            True
# 4                  S           False            True
# 5                  S           False            True
# ...              ...             ...             ...
# 887                S           False            True
# 888                S           False            True
# 889                S           False            True
# 890                C            True           False
# 891                Q           False            True
#
# [891 rows x 3 columns]

# %%
# 국적 컬럼 추가하기
train.loc[train['Embarked'] == 'C', 'Nationality'] = "Austria"
train.loc[train['Embarked'] != 'C', 'Nationality'] = "England"

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
# Fare
train['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
train['LowFare'] = train.Fare < 15
train['MediumFare'] = (train.Fare >= 15) & (train.Fare <= 30)
train['HighFare'] = train.Fare > 30
train[['Fare','LowFare','MediumFare','HighFare']].head(10)
# Out:
#                 Fare  LowFare  MediumFare  HighFare
# PassengerId
# 1             7.2500     True       False     False
# 2            71.2833    False       False      True
# 3             7.9250     True       False     False
# 4            53.1000    False       False      True
# 5             8.0500     True       False     False
# 6             8.4583     True       False     False
# 7            51.8625    False       False      True
# 8            21.0750    False        True     False
# 9            11.1333     True       False     False
# 10           30.0708    False       False      True

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# FareType 컬럼 추가하기
train.loc[train.Fare < 15, 'FareType'] = "Low"
train.loc[(train.Fare >= 15) & (train.Fare <= 30), 'FareType'] = "Medium"
train.loc[train.Fare > 30, 'FareType'] = "High"
train[['Fare','FareType']].head(10)
# Out:
#                 Fare FareType
# PassengerId
# 1             7.2500      Low
# 2            71.2833     High
# 3             7.9250      Low
# 4            53.1000     High
# 5             8.0500      Low
# 6             8.4583      Low
# 7            51.8625     High
# 8            21.0750   Medium
# 9            11.1333      Low
# 10           30.0708     High

# %%
def check_fare_type(fare):
    if fare < 15:
        return "Low"
    elif fare >= 15 and fare < 30:
        return "Medium"
    else:
        return "High"

# %%
train['FareType'] = train['Fare'].apply(check_fare_type)
train[['Fare','FareType']].head(10)
# Out:
#                 Fare FareType
# PassengerId
# 1             7.2500      Low
# 2            71.2833     High
# 3             7.9250      Low
# 4            53.1000     High
# 5             8.0500      Low
# 6             8.4583      Low
# 7            51.8625     High
# 8            21.0750   Medium
# 9            11.1333      Low
# 10           30.0708     High

# %%
# Age의 NaN을 Age의 평균값으로 대체하기 (평균나이는 소수점1자리)
train[train['Age'].isnull()] = round(train['Age'].mean(),1)
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
# null이 아닌 값
sum(train['Age'].notnull())
# Out:
# 891

# %%
# 현재까지의 자료
